# %% [markdown]
# <a href="https://colab.research.google.com/github/kalyankumarboddu/edureka_july4/blob/main/basicchecks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+2
# Out:
# 4

# %%
# getting the CPU/GPU information

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)

if gpu_info.find('failed') > 0:
  print('Not connected to any GPU/CPU')
else:
  print(gpu_info)
  if gpu_info.find('Tesla T4') >= 0:
    print('Sucessfully connected to GPU Tesla T4')
  else:
    print('Connection not established')
# Out:
# Sat Sep  5 09:28:49 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8             15W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
#Setting up the hugging face Key and reading in google colab

from google.colab import userdata
from huggingface_hub import login

hf_token = userdata.get('HF_Token')
login(hf_token, add_to_git_credential=True)

# %%
#Restrating the Kernal through program using Ipython

import IPython

IPython.Application.instance().kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}
